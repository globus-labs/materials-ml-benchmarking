# %% [markdown]
# ## Predicting total energies and enthalpies of formation of metal-nonmetal compounds by linear regression

# %% [markdown]
# Here, we want to study the accuracy and time used to predict variable dataset sizes using the featurizations and algorithms used in [Deml et al paper](https://journals.aps.org/prb/pdf/10.1103/PhysRevB.93.085142)
#
# Referred to `matminer_examples/notebooks/machine-learning/predicting-formation-enthalpy-from-composition.ipynb `

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import pymatgen as pmg
import matplotlib.pyplot as plt

from matminer.utils.conversions import str_to_composition, composition_to_oxidcomposition
from matminer.featurizers.base import MultipleFeaturizer
from matminer.featurizers import composition as cf

from sklearn.utils import shuffle
from sklearn.preprocessing import Imputer, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Lars, LarsCV, LassoLars, lars_path
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_predict, KFold, GridSearchCV
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor

from matplotlib.colors import LogNorm

from pymatgen import MPRester

# %% [markdown]
# ### Loading pickle file

# %%
data = pd.read_pickle('./deml_featurized_data.pkl')

# %% [markdown]
# ### Linear Model: Stepwise Linear Regression

# %% [markdown]
# Remove outliers

# %%
original_count = len(data)
data = data[np.logical_and(data['total_energy'] >= -20, data['total_energy'] <= 5)].reset_index(drop=True)
data = data[np.logical_and(data['delta_e'] >= -20, data['delta_e'] <= 5)].reset_index(drop=True)
print('Removed %d/%d entries'%(original_count - len(data), original_count))
# Out:
# Removed 0/2220 entries

# %%
data.fillna(value=0, inplace=True)
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# Storing formation enthalpy data for later use

# %%
orig_delta_e = data['delta_e']

# %% [markdown]
# Shuffling data and specifying data to be learnt

# %%
data = shuffle(data)

# %%
x = data.drop(['oxidation_states', 'total_energy', 'delta_e', 'composition', 'composition_obj'], 1)
y = data['total_energy']

# %% [markdown]
# Each dataset is randomly divided into three groups:
# - 70% for training the model
# - 15% for preliminary assessment (validation) of model's predictive ability
# - 15% for independent assessment (testing) of model's predictive ability

# %%
n = data.shape[0]
x_train, x_val, x_test = x[:int(n*0.7)], x[int(n*0.7):int(n*0.85)], x[int(n*0.85):]
y_train, y_val, y_test = y[:int(n*0.7)], y[int(n*0.7):int(n*0.85)], y[int(n*0.85):]

# %% [markdown]
# ### Part 3: Quantifying performance of LARS model with different number of candidate descriptors used
#
# Implementation of stepwise linear regression where terms (candidate descriptors) from a linear model are sequentially added or removed according to their effective significance probabilities. In the paper, this approach was implemented in [JMP](https://www.jmp.com/en_us/software/predictive-analytics-software.html). Here, we use recursive feature elimination to assign weights to features and remove features with low weightage.

# %% [markdown]
# 10-fold cross validation was used within the training set to quantify performance of model

# %%
kfold = KFold(10, shuffle=True)

# %% [markdown]
# Number of terms (candidate descriptors) to be used

# %%
num_features = range(10, data.shape[1], 25)

# %% [markdown]
# Initializing mean absolute error, mean squared error and R2 score

# %%
score_train = {"r2_score": [], "mean_absolute_error": [], "mean_squared_error": []}
score_val = {"r2_score": [], "mean_absolute_error": [], "mean_squared_error": []}
score_test = {"r2_score": [], "mean_absolute_error": [], "mean_squared_error": []}

# %% [markdown]
# Training the Least Angle Regression (LARS) model with variable number of features used and quantifying the performance.

# %%
for i in num_features:
    selector = Lars(n_nonzero_coefs=i, eps=1e-6)
    selector = selector.fit(x_train, y_train)
    cv_train = cross_val_predict(selector, x_train, y_train, cv=kfold) 
    cv_val = cross_val_predict(selector, x_val, y_val, cv=kfold)
    cv_test = cross_val_predict(selector, x_test, y_test, cv=kfold)
    for scorer in ['r2_score', 'mean_absolute_error', 'mean_squared_error']:
        score_train[scorer].append(getattr(metrics,scorer)(y_train, cv_train))
        score_val[scorer].append(getattr(metrics,scorer)(y_val, cv_val))
        score_test[scorer].append(getattr(metrics,scorer)(y_test, cv_test))

# %% [markdown]
# Plot the model performance when number of terms (candidate descriptors) is changed.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True)

ax3.set_xlabel("Num of features")
ax1.set_ylabel("R2")
ax2.set_ylabel("MAE (eV/atom)")
ax3.set_ylabel("MSE (eV/atom)")

ax1.plot(num_features, score_train['r2_score'], c='grey', marker='.', label='Training')
ax1.plot(num_features, score_val['r2_score'], c='orange', marker='.', label='Validation')
ax1.plot(num_features, score_test['r2_score'], c='blue', marker='.', label='Testing')

ax2.plot(num_features, score_train['mean_absolute_error'], c='grey', marker='.', label='Training')
ax2.plot(num_features, score_val['mean_absolute_error'], c='orange', marker='.', label='Validation')
ax2.plot(num_features, score_test['mean_absolute_error'], c='blue', marker='.', label='Testing')

ax3.plot(num_features, score_train['mean_squared_error'], c='grey', marker='.', label='Training')
ax3.plot(num_features, score_val['mean_squared_error'], c='orange', marker='.', label='Validation')
ax3.plot(num_features, score_test['mean_squared_error'], c='blue', marker='.', label='Testing')

ax2.legend()

fig.set_size_inches(6, 6)
fig.subplots_adjust(hspace=0.01)

# %% [markdown]
# _Best_: Using 10 terms. (INTRIGUING)
#
# Prediction is way better using `energy_per_atom` instead of `energy`.

# %% [markdown]
# ### Choose to use between Lars or LassoLars model for total energy prediction.

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
#     selector = Lars(n_nonzero_coefs=10)
    selector = LassoLars(alpha=0.00000001)
    selector = selector.fit(x_train, y_train)

# %%
cv_train = cross_val_predict(selector, x_train, y_train, cv=kfold) 
cv_val = cross_val_predict(selector, x_val, y_val, cv=kfold)
cv_test = cross_val_predict(selector, x_test, y_test, cv=kfold)
# Out:
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 270 iterations, i.e. alpha=3.703e-05, with an active set of 112 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 270 iterations, i.e. alpha=3.703e-05, with an active set of 112 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 270 iterations, i.e. alpha=3.703e-05, with an active set of 112 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 348 iterations, i.e. alpha=1.851e-05, with an active set of 130 regressors, and the smallest cholesky pivot element being 4.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 348 iterations, i.e. alpha=1.851e-05, with an active set of 130 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 406 iterations, i.e. alpha=1.109e-05, with an active set of 144 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 407 iterations, i.e. alpha=1.105e-05, with an active set of 145 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 408 iterations, i.e. alpha=1.101e-05, with an active set of 146 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 408 iterations, i.e. alpha=1.101e-05, with an active set of 146 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 408 iterations, i.e. alpha=1.085e-05, with an active set of 146 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 409 iterations, alpha=1.100e-05, previous alpha=1.084e-05, with an active set of 146 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=7.340e-04, with an active set of 42 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.262e-04, with an active set of 43 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=7.262e-04, with an active set of 43 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 77 iterations, i.e. alpha=6.306e-04, with an active set of 47 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 99 iterations, i.e. alpha=3.631e-04, with an active set of 55 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 99 iterations, i.e. alpha=3.631e-04, with an active set of 55 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 132 iterations, alpha=3.203e-04, previous alpha=3.177e-04, with an active set of 59 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=8.368e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=8.368e-04, with an active set of 38 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 65 iterations, i.e. alpha=8.356e-04, with an active set of 39 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 65 iterations, i.e. alpha=8.356e-04, with an active set of 39 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 77 iterations, i.e. alpha=4.184e-04, with an active set of 47 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 78 iterations, i.e. alpha=4.175e-04, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 80 iterations, i.e. alpha=3.976e-04, with an active set of 50 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 82 iterations, alpha=3.942e-04, previous alpha=3.928e-04, with an active set of 51 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=2.397e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=2.385e-03, with an active set of 23 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=1.192e-03, with an active set of 30 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=1.192e-03, with an active set of 30 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 83 iterations, alpha=1.007e-03, previous alpha=1.006e-03, with an active set of 40 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 99 iterations, i.e. alpha=3.320e-04, with an active set of 53 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 100 iterations, i.e. alpha=3.316e-04, with an active set of 54 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 147 iterations, i.e. alpha=1.689e-04, with an active set of 71 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 148 iterations, i.e. alpha=1.665e-04, with an active set of 72 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 152 iterations, i.e. alpha=1.658e-04, with an active set of 74 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 153 iterations, i.e. alpha=1.655e-04, with an active set of 75 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 155 iterations, alpha=1.641e-04, previous alpha=1.637e-04, with an active set of 76 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 70 iterations, i.e. alpha=7.068e-04, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 95 iterations, i.e. alpha=3.547e-04, with an active set of 51 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=3.541e-04, with an active set of 52 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=3.541e-04, with an active set of 52 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 99 iterations, i.e. alpha=3.314e-04, with an active set of 53 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 105 iterations, i.e. alpha=3.034e-04, with an active set of 57 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 136 iterations, i.e. alpha=1.959e-04, with an active set of 72 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 145 iterations, i.e. alpha=1.771e-04, with an active set of 77 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 148 iterations, alpha=1.738e-04, previous alpha=1.737e-04, with an active set of 79 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 77 iterations, i.e. alpha=5.475e-04, with an active set of 47 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 77 iterations, i.e. alpha=5.475e-04, with an active set of 47 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 113 iterations, i.e. alpha=2.737e-04, with an active set of 65 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 114 iterations, alpha=2.711e-04, previous alpha=2.702e-04, with an active set of 65 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 329 iterations, i.e. alpha=1.302e-05, with an active set of 143 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 440 iterations, alpha=8.758e-06, previous alpha=4.220e-06, with an active set of 167 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 73 iterations, i.e. alpha=6.323e-04, with an active set of 39 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.295e-04, with an active set of 40 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 74 iterations, i.e. alpha=6.295e-04, with an active set of 40 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 98 iterations, i.e. alpha=3.587e-04, with an active set of 56 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 110 iterations, i.e. alpha=3.148e-04, with an active set of 60 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 111 iterations, alpha=3.146e-04, previous alpha=3.142e-04, with an active set of 60 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=2.808e-03, with an active set of 20 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 37 iterations, i.e. alpha=2.476e-03, with an active set of 23 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=2.474e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=2.387e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=1.932e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 44 iterations, i.e. alpha=1.719e-03, with an active set of 30 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 51 iterations, i.e. alpha=1.238e-03, with an active set of 33 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 51 iterations, i.e. alpha=1.234e-03, with an active set of 33 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 53 iterations, alpha=1.219e-03, previous alpha=1.205e-03, with an active set of 32 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 63 iterations, i.e. alpha=8.400e-04, with an active set of 39 regressors, and the smallest cholesky pivot element being 7.224e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 123 iterations, alpha=3.784e-04, previous alpha=3.783e-04, with an active set of 58 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 54 iterations, i.e. alpha=9.063e-04, with an active set of 36 regressors, and the smallest cholesky pivot element being 8.752e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=9.023e-04, with an active set of 37 regressors, and the smallest cholesky pivot element being 8.752e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 93 iterations, i.e. alpha=4.430e-04, with an active set of 51 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 94 iterations, alpha=4.428e-04, previous alpha=4.401e-04, with an active set of 51 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 43 iterations, i.e. alpha=1.869e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 7.955e-08. Reduce max_iter or increase eps parameters.
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 64 iterations, i.e. alpha=8.409e-04, with an active set of 36 regressors, and the smallest cholesky pivot element being 7.671e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 84 iterations, i.e. alpha=4.739e-04, with an active set of 48 regressors, and the smallest cholesky pivot element being 7.814e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 88 iterations, alpha=4.512e-04, previous alpha=4.507e-04, with an active set of 51 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 54 iterations, i.e. alpha=1.126e-03, with an active set of 32 regressors, and the smallest cholesky pivot element being 8.162e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 92 iterations, i.e. alpha=5.294e-04, with an active set of 48 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=5.235e-04, with an active set of 50 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=5.235e-04, with an active set of 50 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=5.235e-04, with an active set of 50 regressors, and the smallest cholesky pivot element being 4.081e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=5.207e-04, with an active set of 50 regressors, and the smallest cholesky pivot element being 8.297e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 98 iterations, alpha=5.221e-04, previous alpha=5.184e-04, with an active set of 51 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 89 iterations, i.e. alpha=5.117e-04, with an active set of 47 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 90 iterations, i.e. alpha=5.116e-04, with an active set of 48 regressors, and the smallest cholesky pivot element being 3.332e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 109 iterations, i.e. alpha=3.075e-04, with an active set of 57 regressors, and the smallest cholesky pivot element being 7.224e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 162 iterations, alpha=1.799e-04, previous alpha=1.790e-04, with an active set of 75 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 379 iterations, i.e. alpha=1.122e-05, with an active set of 147 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 392 iterations, i.e. alpha=1.022e-05, with an active set of 150 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 393 iterations, i.e. alpha=1.021e-05, with an active set of 151 regressors, and the smallest cholesky pivot element being 2.980e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 393 iterations, i.e. alpha=1.021e-05, with an active set of 151 regressors, and the smallest cholesky pivot element being 4.712e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 393 iterations, i.e. alpha=1.019e-05, with an active set of 151 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 395 iterations, i.e. alpha=9.954e-06, with an active set of 153 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 397 iterations, alpha=9.966e-06, previous alpha=9.913e-06, with an active set of 154 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 59 iterations, i.e. alpha=1.094e-03, with an active set of 33 regressors, and the smallest cholesky pivot element being 6.495e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 418 iterations, i.e. alpha=5.499e-05, with an active set of 142 regressors, and the smallest cholesky pivot element being 3.161e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 122 iterations, i.e. alpha=1.957e-04, with an active set of 68 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 122 iterations, i.e. alpha=1.957e-04, with an active set of 68 regressors, and the smallest cholesky pivot element being 7.451e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 122 iterations, i.e. alpha=1.957e-04, with an active set of 68 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 136 iterations, i.e. alpha=1.461e-04, with an active set of 78 regressors, and the smallest cholesky pivot element being 5.373e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 137 iterations, alpha=1.446e-04, previous alpha=1.443e-04, with an active set of 78 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 62 iterations, i.e. alpha=9.260e-04, with an active set of 36 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 138 iterations, i.e. alpha=2.061e-04, with an active set of 70 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 242 iterations, i.e. alpha=7.374e-05, with an active set of 104 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 243 iterations, i.e. alpha=7.374e-05, with an active set of 105 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 320 iterations, alpha=4.325e-05, previous alpha=4.322e-05, with an active set of 123 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=2.243e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 3.799e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 31 iterations, i.e. alpha=2.237e-03, with an active set of 23 regressors, and the smallest cholesky pivot element being 3.650e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 47 iterations, alpha=1.216e-03, previous alpha=1.214e-03, with an active set of 36 regressors.

# %% [markdown]
# Plot the predictions

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True)

fig.suptitle('Total Energy Prediction', fontsize=14, x=0.53, y=1.02)

# Training and Validation plot
mae_train = metrics.mean_absolute_error(y_train, cv_train)
r2_train = metrics.r2_score(y_train, cv_train)
mae_val = metrics.mean_absolute_error(y_val, cv_val)
r2_val = metrics.r2_score(y_val, cv_val)
ax1.text(0.65, 0.026, 'Training:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}\nValidation:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_train, r2_train, mae_val, r2_val),
        transform=ax1.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})

ax1.scatter(y_train, cv_train, c='grey', marker='s', label='Training')
ax1.scatter(y_val, cv_val, c='orange', marker='^', label='Validation')
ax1.plot(ax1.get_xlim(), ax1.get_xlim(), 'k--')

ax1.legend()

ax1.set_title('Training & Validation')
ax1.set_xlabel('DFT Total_Energy (eV/atom)')
ax1.set_ylabel('ML Total_energy (eV/atom)')

# Testing plot
mae_test = metrics.mean_absolute_error(y_test, cv_test)
r2_test = metrics.r2_score(y_test, cv_test)
ax2.text(0.65, 0.026, 'Testing:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_test, r2_test),
        transform=ax2.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})
ax2.scatter(y_test, cv_test, c='b', marker='o', label='Testing')
ax2.plot(ax2.get_xlim(), ax2.get_xlim(), 'k--')

ax2.legend()

ax2.set_title('Testing')
ax2.set_xlabel('DFT Total_Energy (eV/atom)')

fig.set_size_inches(10, 7)
fig.subplots_adjust(hspace=0)
fig.tight_layout()

# %% [markdown]
# ### Prediction of formation enthalpy

# %%
ML_delta_e = pd.Series(index=np.arange(data.shape[0]))

# %%
ML_total_energy = selector.predict(x)

# %% [markdown]
# Importing fitted elemental phase reference energies, $\mu^{FERE}$ from `matminer.utils.data_files.deml_elementdata`

# %%
from matminer.utils.data_files.deml_elementdata import mus_fere

# %% [markdown]
# Using total energy value to compute formation energy according to the equation
# $$\Delta H_f = E_{tot} - \Sigma_i c_i \mu_i^{FERE}$$

# %%
for i in range(data.shape[0]):
    fere = (float(data['composition_obj'][i][str(j)])/data['composition_obj'][i].num_atoms*mus_fere[str(j)] for j in (data['composition_obj'][i]))
    fere = sum(fere)
    ML_delta_e[i] = ML_total_energy[i] - fere

# %% [markdown]
# Partitioning both ML and DFT formation enthalpy data into training, validation and testing sets.

# %%
DFT_delta_e = orig_delta_e
ML_delta_e, DFT_delta_e = shuffle(ML_delta_e, DFT_delta_e)
dft_train, dft_val, dft_test = DFT_delta_e[:int(n*0.7)], DFT_delta_e[int(n*0.7):int(n*0.85)], DFT_delta_e[int(n*0.85):]
ml_train, ml_val, ml_test = ML_delta_e[:int(n*0.7)], ML_delta_e[int(n*0.7):int(n*0.85)], ML_delta_e[int(n*0.85):]

# %% [markdown]
# Plot the prediction of formation enthalpy

# %%
mae_train = metrics.mean_absolute_error(ml_train, dft_train)
mae_val = metrics.mean_absolute_error(ml_val, dft_val)
mae_test = metrics.mean_absolute_error(ml_test, dft_test)

r2_train = metrics.r2_score(ml_train, dft_train)
r2_val = metrics.r2_score(ml_val, dft_val)
r2_test = metrics.r2_score(ml_test, dft_test)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True)

fig.suptitle('Formation Enthalpy Prediction', fontsize=14, x=0.53, y=1.02)

ax1.set_title('Training & Validation')
ax1.set_xlabel('DFT $\Delta H_f$ (eV/atom)')
ax1.set_ylabel('ML $\Delta H_f$ (eV/atom)')
ax1.scatter(dft_train, ml_train, c='grey', marker='s', label='Training')
ax1.scatter(dft_val, ml_val, c='orange', marker='^', label='Validation')
ax1.plot(ax1.get_xlim(), ax1.get_xlim(), 'k--')
ax1.text(0.65, 0.026, 'Training:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}\nValidation:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_train, r2_train, mae_val, r2_val),
        transform=ax1.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})
ax1.legend()

ax2.set_title('Testing')
ax2.set_xlabel('DFT $\Delta H_f$ (eV/atom)')
ax2.scatter(dft_test, ml_test, c='b', marker='o', label='Testing')
ax2.plot(ax2.get_xlim(), ax2.get_xlim(), 'k--')
ax2.text(0.65, 0.026, 'Testing:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_test, r2_test),
        transform=ax2.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})
ax2.legend()

fig.set_size_inches(10, 7)
fig.tight_layout()

# %% [markdown]
# ***Large mean absolute error as compared to ~80 meV/atom in paper.***

# %% [markdown]
# ## PREDICTION OF FORMATION ENTHALPY DIRECTLY (LARS/LassoLars)

# %%
data = shuffle(data)

# %%
x = data.drop(['oxidation_states', 'total_energy', 'delta_e', 'composition', 'composition_obj'], 1)
y = data['delta_e']

# %% [markdown]
# Dividing datasets into training, validation and testing sets

# %%
n = data.shape[0]
x_train, x_val, x_test = x[:int(n*0.7)], x[int(n*0.7):int(n*0.85)], x[int(n*0.85):]
y_train, y_val, y_test = y[:int(n*0.7)], y[int(n*0.7):int(n*0.85)], y[int(n*0.85):]

# %% [markdown]
# Training LARS / LassoLars model

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
#     selector = Lars(n_nonzero_coefs=10)
    selector = LassoLars(alpha=0.00000001)
    selector = selector.fit(x_train, y_train)

# %%
cv_train = cross_val_predict(selector, x_train, y_train, cv=kfold) 
cv_val = cross_val_predict(selector, x_val, y_val, cv=kfold)
cv_test = cross_val_predict(selector, x_test, y_test, cv=kfold)
# Out:
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 81 iterations, i.e. alpha=1.774e-04, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.825e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 280 iterations, i.e. alpha=3.719e-05, with an active set of 116 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 283 iterations, i.e. alpha=3.714e-05, with an active set of 117 regressors, and the smallest cholesky pivot element being 2.581e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 283 iterations, i.e. alpha=3.709e-05, with an active set of 117 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 283 iterations, i.e. alpha=3.694e-05, with an active set of 117 regressors, and the smallest cholesky pivot element being 2.788e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 285 iterations, alpha=3.698e-05, previous alpha=3.646e-05, with an active set of 118 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 417 iterations, i.e. alpha=5.860e-06, with an active set of 155 regressors, and the smallest cholesky pivot element being 8.816e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 211 iterations, i.e. alpha=5.537e-05, with an active set of 91 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 339 iterations, i.e. alpha=1.622e-05, with an active set of 135 regressors, and the smallest cholesky pivot element being 4.470e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 340 iterations, i.e. alpha=1.618e-05, with an active set of 136 regressors, and the smallest cholesky pivot element being 4.215e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 342 iterations, alpha=1.595e-05, previous alpha=1.592e-05, with an active set of 137 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 250 iterations, i.e. alpha=2.911e-05, with an active set of 110 regressors, and the smallest cholesky pivot element being 7.598e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 251 iterations, i.e. alpha=2.910e-05, with an active set of 111 regressors, and the smallest cholesky pivot element being 7.671e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 325 iterations, i.e. alpha=1.456e-05, with an active set of 143 regressors, and the smallest cholesky pivot element being 7.814e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 487 iterations, i.e. alpha=7.406e-06, with an active set of 157 regressors, and the smallest cholesky pivot element being 8.025e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 488 iterations, alpha=7.401e-06, previous alpha=7.394e-06, with an active set of 157 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 403 iterations, i.e. alpha=5.230e-06, with an active set of 163 regressors, and the smallest cholesky pivot element being 5.162e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 406 iterations, alpha=5.093e-06, previous alpha=5.085e-06, with an active set of 165 regressors.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 176 iterations, i.e. alpha=8.103e-05, with an active set of 78 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 330 iterations, i.e. alpha=1.405e-05, with an active set of 124 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:313: ConvergenceWarning:
#
# Regressors in active set degenerate. Dropping a regressor, after 330 iterations, i.e. alpha=1.400e-05, with an active set of 124 regressors, and the smallest cholesky pivot element being 2.107e-08. Reduce max_iter or increase eps parameters.
#
# /Users/AikRui/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning:
#
# Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 334 iterations, alpha=1.358e-05, previous alpha=1.352e-05, with an active set of 127 regressors.

# %% [markdown]
# Plot the predictions

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True)

fig.suptitle('Formation Enthalpy Prediction', fontsize=14, x=0.53, y=1.02)

# Training and Validation plot
mae_train = metrics.mean_absolute_error(y_train, cv_train)
r2_train = metrics.r2_score(y_train, cv_train)
mae_val = metrics.mean_absolute_error(y_val, cv_val)
r2_val = metrics.r2_score(y_val, cv_val)
ax1.text(0.65, 0.026, 'Training:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}\nValidation:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_train, r2_train, mae_val, r2_val),
        transform=ax1.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})

ax1.scatter(y_train, cv_train, c='grey', marker='s', label='Training')
ax1.scatter(y_val, cv_val, c='orange', marker='^', label='Validation')
ax1.plot(ax1.get_xlim(), ax1.get_xlim(), 'k--')

ax1.legend()

ax1.set_title('Training & Validation')
ax1.set_xlabel('DFT Formation Enthalpy (eV/atom)')
ax1.set_ylabel('ML Formation Enthalpy (eV/atom)')

# Testing plot
mae_test = metrics.mean_absolute_error(y_test, cv_test)
r2_test = metrics.r2_score(y_test, cv_test)
ax2.text(0.65, 0.026, 'Testing:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_test, r2_test),
        transform=ax2.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})
ax2.scatter(y_test, cv_test, c='b', marker='o', label='Testing')
ax2.plot(ax2.get_xlim(), ax2.get_xlim(), 'k--')

ax2.legend()

ax2.set_title('Testing')
ax2.set_xlabel('DFT Formation Enthalpy (eV/atom)')

fig.set_size_inches(10, 7)
fig.subplots_adjust(hspace=0)
fig.tight_layout()

# %% [markdown]
# # Using RandomForestRegressor model
#
# We're trying to study if the bad prediction using Least Angle Regression linear model is due to the lack of nonlinear features.

# %%
data = shuffle(data)

# %%
x = data.drop(['oxidation_states', 'total_energy', 'delta_e', 'composition', 'composition_obj'], 1)
y = data['total_energy']

# %% [markdown]
# Dividing datasets into training, validation and testing sets

# %%
n = data.shape[0]
x_train, x_val, x_test = x[:int(n*0.7)], x[int(n*0.7):int(n*0.85)], x[int(n*0.85):]
y_train, y_val, y_test = y[:int(n*0.7)], y[int(n*0.7):int(n*0.85)], y[int(n*0.85):]

# %% [markdown]
# Using GridSearchCV to find the optimal number of features.

# %%
model = GridSearchCV(RandomForestRegressor(n_estimators=100),
                     param_grid=dict(max_features=range(10, data.shape[1], 50)),
                     scoring='neg_mean_squared_error', 
                     cv=kfold)

# %%
# %%time
model.fit(x_train, y_train)
# Out:
# CPU times: user 11min 24s, sys: 6.02 s, total: 11min 30s
# Wall time: 11min 47s
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#        error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_features': range(10, 370, 50)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %% [markdown]
# Plot RMSE as a function of features used

# %%
fig, ax = plt.subplots()

# Plot the score as a function of alpha
ax.scatter(model.cv_results_['param_max_features'].data,
          np.sqrt(-1 * model.cv_results_['mean_test_score']))
ax.scatter([model.best_params_['max_features']], np.sqrt([-1*model.best_score_]), marker='o', color='r', s=40)
ax.set_xlabel('Max. Features')
ax.set_ylabel('RMSE (eV/atom)')
# Out:
# Text(0,0.5,'RMSE (eV/atom)')

# %%
model = model.best_estimator_

# %% [markdown]
# Cross validated prediction of training, validation and testing sets.

# %%
cv_train = cross_val_predict(model, x_train, y_train, cv=kfold) 
cv_val = cross_val_predict(model, x_val, y_val, cv=kfold)
cv_test = cross_val_predict(model, x_test, y_test, cv=kfold)

# %% [markdown]
# Plot the prediction of total energy

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True)

fig.suptitle('Total Energy Prediction', fontsize=14, x=0.53, y=1.02)

# Training and Validation plot
mae_train = metrics.mean_absolute_error(y_train, cv_train)
r2_train = metrics.r2_score(y_train, cv_train)
mae_val = metrics.mean_absolute_error(y_val, cv_val)
r2_val = metrics.r2_score(y_val, cv_val)
ax1.text(0.65, 0.026, 'Training:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}\nValidation:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_train, r2_train, mae_val, r2_val),
        transform=ax1.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})

ax1.scatter(y_train, cv_train, c='grey', marker='s', label='Training')
ax1.scatter(y_val, cv_val, c='orange', marker='^', label='Validation')
ax1.plot(ax1.get_xlim(), ax1.get_xlim(), 'k--')

ax1.legend()

ax1.set_title('Training & Validation')
ax1.set_xlabel('DFT Total_Energy (eV/atom)')
ax1.set_ylabel('ML Total_energy (eV/atom)')

# Testing plot
mae_test = metrics.mean_absolute_error(y_test, cv_test)
r2_test = metrics.r2_score(y_test, cv_test)
ax2.text(0.65, 0.026, 'Testing:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_test, r2_test),
        transform=ax2.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})
ax2.scatter(y_test, cv_test, c='b', marker='o', label='Testing')
ax2.plot(ax2.get_xlim(), ax2.get_xlim(), 'k--')

ax2.legend()

ax2.set_title('Testing')
ax2.set_xlabel('DFT Total_Energy (eV/atom)')

fig.set_size_inches(10, 7)
fig.subplots_adjust(hspace=0)
fig.tight_layout()

# %% [markdown]
# ### Prediction of formation enthalpy

# %%
ML_delta_e = pd.Series(index=np.arange(data.shape[0]))

# %%
ML_total_energy = model.predict(x)

# %% [markdown]
# Importing fitted elemental phase reference energies, $\mu^{FERE}$ from `matminer.utils.data_files.deml_elementdata`

# %%
from matminer.utils.data_files.deml_elementdata import mus_fere

# %% [markdown]
# Using total energy value to compute formation energy according to the equation
# $$\Delta H_f = E_{tot} - \Sigma_i c_i \mu_i^{FERE}$$

# %%
for i in range(data.shape[0]):
    fere = (float(data['composition_obj'][i][str(j)])/data['composition_obj'][i].num_atoms*mus_fere[str(j)] for j in (data['composition_obj'][i]))
    fere = sum(fere)
    ML_delta_e[i] = ML_total_energy[i] - fere

# %% [markdown]
# Partitioning both ML and DFT formation enthalpy data into training, validation and testing sets.

# %%
DFT_delta_e = orig_delta_e
ML_delta_e, DFT_delta_e = shuffle(ML_delta_e, DFT_delta_e)
dft_train, dft_val, dft_test = DFT_delta_e[:int(n*0.7)], DFT_delta_e[int(n*0.7):int(n*0.85)], DFT_delta_e[int(n*0.85):]
ml_train, ml_val, ml_test = ML_delta_e[:int(n*0.7)], ML_delta_e[int(n*0.7):int(n*0.85)], ML_delta_e[int(n*0.85):]

# %% [markdown]
# Plot the prediction of formation enthalpy

# %%
mae_train = metrics.mean_absolute_error(ml_train, dft_train)
mae_val = metrics.mean_absolute_error(ml_val, dft_val)
mae_test = metrics.mean_absolute_error(ml_test, dft_test)

r2_train = metrics.r2_score(ml_train, dft_train)
r2_val = metrics.r2_score(ml_val, dft_val)
r2_test = metrics.r2_score(ml_test, dft_test)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True)

fig.suptitle('Formation Enthalpy Prediction', fontsize=14, x=0.53, y=1.02)

ax1.set_title('Training & Validation')
ax1.set_xlabel('DFT $\Delta H_f$ (eV/atom)')
ax1.set_ylabel('ML $\Delta H_f$ (eV/atom)')
ax1.scatter(dft_train, ml_train, c='grey', marker='s', label='Training')
ax1.scatter(dft_val, ml_val, c='orange', marker='^', label='Validation')
ax1.plot(ax1.get_xlim(), ax1.get_xlim(), 'k--')
ax1.text(0.65, 0.026, 'Training:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}\nValidation:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_train, r2_train, mae_val, r2_val),
        transform=ax1.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})
ax1.legend()

ax2.set_title('Testing')
ax2.set_xlabel('DFT $\Delta H_f$ (eV/atom)')
ax2.scatter(dft_test, ml_test, c='b', marker='o', label='Testing')
ax2.plot(ax2.get_xlim(), ax2.get_xlim(), 'k--')
ax2.text(0.65, 0.026, 'Testing:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_test, r2_test),
        transform=ax2.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})
ax2.legend()

fig.set_size_inches(10, 7)
fig.tight_layout()

# %% [markdown]
# ## PREDICTION OF FORMATION ENTHALPY DIRECTLY (RandomForest)

# %%
data = shuffle(data)

# %%
x = data.drop(['oxidation_states', 'total_energy', 'delta_e', 'composition', 'composition_obj'], 1)
y = data['delta_e']

# %% [markdown]
# Dividing datasets into training, validation and testing sets

# %%
n = data.shape[0]
x_train, x_val, x_test = x[:int(n*0.7)], x[int(n*0.7):int(n*0.85)], x[int(n*0.85):]
y_train, y_val, y_test = y[:int(n*0.7)], y[int(n*0.7):int(n*0.85)], y[int(n*0.85):]

# %% [markdown]
# Using GridSearchCV to find the optimal number of features.

# %%
model = GridSearchCV(RandomForestRegressor(n_estimators=100),
                     param_grid=dict(max_features=range(10, data.shape[1], 50)),
                     scoring='neg_mean_squared_error', 
                     cv=kfold)

# %%
# %%time
model.fit(x_train, y_train)
# Out:
# CPU times: user 11min 28s, sys: 5.27 s, total: 11min 33s
# Wall time: 11min 51s
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#        error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_features': range(10, 370, 50)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %% [markdown]
# Plot RMSE as a function of features used

# %%
fig, ax = plt.subplots()

# Plot the score as a function of alpha
ax.scatter(model.cv_results_['param_max_features'].data,
          np.sqrt(-1 * model.cv_results_['mean_test_score']))
ax.scatter([model.best_params_['max_features']], np.sqrt([-1*model.best_score_]), marker='o', color='r', s=40)
ax.set_xlabel('Max. Features')
ax.set_ylabel('RMSE (eV/atom)')
# Out:
# Text(0,0.5,'RMSE (eV/atom)')

# %%
model = model.best_estimator_

# %% [markdown]
# Cross validated prediction of training, validation and testing sets.

# %%
cv_train = cross_val_predict(model, x_train, y_train, cv=kfold) 
cv_val = cross_val_predict(model, x_val, y_val, cv=kfold)
cv_test = cross_val_predict(model, x_test, y_test, cv=kfold)

# %% [markdown]
# Plot the predictions

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True)

fig.suptitle('Formation Enthalpy Prediction', fontsize=14, x=0.53, y=1.02)

# Training and Validation plot
mae_train = metrics.mean_absolute_error(y_train, cv_train)
r2_train = metrics.r2_score(y_train, cv_train)
mae_val = metrics.mean_absolute_error(y_val, cv_val)
r2_val = metrics.r2_score(y_val, cv_val)
ax1.text(0.65, 0.026, 'Training:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}\nValidation:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_train, r2_train, mae_val, r2_val),
        transform=ax1.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})

ax1.scatter(y_train, cv_train, c='grey', marker='s', label='Training')
ax1.scatter(y_val, cv_val, c='orange', marker='^', label='Validation')
ax1.plot(ax1.get_xlim(), ax1.get_xlim(), 'k--')

ax1.legend()

ax1.set_title('Training & Validation')
ax1.set_xlabel('DFT Formation Enthalpy (eV/atom)')
ax1.set_ylabel('ML Formation Enthalpy (eV/atom)')

# Testing plot
mae_test = metrics.mean_absolute_error(y_test, cv_test)
r2_test = metrics.r2_score(y_test, cv_test)
ax2.text(0.65, 0.026, 'Testing:\nMAE: {:.3f} eV/atom\n$R^2$:  {:.3f}'.format(mae_test, r2_test),
        transform=ax2.transAxes,
       bbox={'facecolor': 'w', 'edgecolor': 'k'})
ax2.scatter(y_test, cv_test, c='b', marker='o', label='Testing')
ax2.plot(ax2.get_xlim(), ax2.get_xlim(), 'k--')

ax2.legend()

ax2.set_title('Testing')
ax2.set_xlabel('DFT Formation Enthalpy (eV/atom)')

fig.set_size_inches(10, 7)
fig.subplots_adjust(hspace=0)
fig.tight_layout()

# %% [markdown]
# *Finding*: Direct prediction of formation enthalpy is much better. There is a mean absolute error of ~170 meV/atom.
